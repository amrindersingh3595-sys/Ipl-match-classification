# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('ipl.csv')
print(df)
# Out:
#           id   season        city       date match_type player_of_match  \
# 0     335982  2007/08   Bangalore  4/18/2008     League     BB McCullum
# 1     335983  2007/08  Chandigarh  4/19/2008     League      MEK Hussey
# 2     335984  2007/08       Delhi  4/19/2008     League     MF Maharoof
# 3     335985  2007/08      Mumbai  4/20/2008     League      MV Boucher
# 4     335986  2007/08     Kolkata  4/20/2008     League       DJ Hussey
# ..       ...      ...         ...        ...        ...             ...
# 699  1175359     2019      Jaipur  3/25/2019     League        CH Gayle
# 700  1175360     2019       Delhi  3/26/2019     League       SR Watson
# 701  1175361     2019     Kolkata  3/27/2019     League      AD Russell
# 702  1175362     2019   Bengaluru  3/28/2019     League       JJ Bumrah
# 703  1175363     2019   Hyderabad  3/29/2019     League     Rashid Khan
#
#                                           venue                        team1  \
# ...

# %%
df.head(10)
# Out:
#        id   season        city       date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  4/18/2008     League     BB McCullum
# 1  335983  2007/08  Chandigarh  4/19/2008     League      MEK Hussey
# 2  335984  2007/08       Delhi  4/19/2008     League     MF Maharoof
# 3  335985  2007/08      Mumbai  4/20/2008     League      MV Boucher
# 4  335986  2007/08     Kolkata  4/20/2008     League       DJ Hussey
# 5  335987  2007/08      Jaipur  4/21/2008     League       SR Watson
# 6  335988  2007/08   Hyderabad  4/22/2008     League        V Sehwag
# 7  335989  2007/08     Chennai  4/23/2008     League       ML Hayden
# 8  335990  2007/08   Hyderabad  4/24/2008     League       YK Pathan
# 9  335991  2007/08  Chandigarh  4/25/2008     League   KC Sangakkara
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# ...

# %%
df.tail(10)
# Out:
#           id season       city       date   match_type  player_of_match  \
# 694  1136619   2018    Kolkata  5/25/2018  Qualifier 2      Rashid Khan
# 695  1136620   2018     Mumbai  5/27/2018        Final        SR Watson
# 696  1175356   2019    Chennai  3/23/2019       League  Harbhajan Singh
# 697  1175357   2019    Kolkata  3/24/2019       League       AD Russell
# 698  1175358   2019     Mumbai  3/24/2019       League          RR Pant
# 699  1175359   2019     Jaipur  3/25/2019       League         CH Gayle
# 700  1175360   2019      Delhi  3/26/2019       League        SR Watson
# 701  1175361   2019    Kolkata  3/27/2019       League       AD Russell
# 702  1175362   2019  Bengaluru  3/28/2019       League        JJ Bumrah
# 703  1175363   2019  Hyderabad  3/29/2019       League      Rashid Khan
#
#                                   venue                        team1  \
# 694                        Eden Gardens          Sunrisers Hyderabad
# ...

# %%
df.count()
# Out:
# id                 704
# season             704
# city               691
# date               704
# match_type         704
# player_of_match    701
# venue              704
# team1              704
# team2              704
# toss_winner        704
# toss_decision      704
# winner             701
# result             704
# result_margin      694
# target_runs        702
# target_overs       702
# super_over         704
# method              19
# umpire1            704
# umpire2            704
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df.groupby('city').size()
# Out:
# city
# Abu Dhabi          7
# Ahmedabad         12
# Bangalore         65
# Bengaluru          9
# Bloemfontein       2
# Cape Town          7
# Centurion         12
# Chandigarh        49
# Chennai           50
# Cuttack            7
# Delhi             68
# Dharamsala         9
# Durban            15
# East London        3
# Hyderabad         57
# Indore             9
# Jaipur            41
# Johannesburg       8
# Kanpur             4
# Kimberley          3
# Kochi              5
# Kolkata           72
# Mumbai            95
# Nagpur             3
# Port Elizabeth     7
# Pune              38
# Raipur             6
# Rajkot            10
# Ranchi             7
# Visakhapatnam     11
# dtype: int64

# %%
df.groupby('season').size()
# Out:
# season
# 2007/08    58
# 2009       57
# 2009/10    60
# 2011       73
# 2012       74
# 2013       76
# 2014       60
# 2015       59
# 2016       60
# 2017       59
# 2018       60
# 2019        8
# dtype: int64

# %%
df[df['toss_winner']==df['winner']]
# Out:
#           id   season        city       date   match_type  player_of_match  \
# 1     335983  2007/08  Chandigarh  4/19/2008       League       MEK Hussey
# 8     335990  2007/08   Hyderabad  4/24/2008       League        YK Pathan
# 10    335992  2007/08   Bangalore  4/26/2008       League        SR Watson
# 12    335994  2007/08      Mumbai  4/27/2008       League     AC Gilchrist
# 14    335996  2007/08   Bangalore  4/28/2008       League         MS Dhoni
# ..       ...      ...         ...        ...          ...              ...
# 691  1136616     2018        Pune  5/20/2018       League          L Ngidi
# 692  1136617     2018      Mumbai  5/22/2018  Qualifier 1     F du Plessis
# 695  1136620     2018      Mumbai  5/27/2018        Final        SR Watson
# 696  1175356     2019     Chennai  3/23/2019       League  Harbhajan Singh
# 697  1175357     2019     Kolkata  3/24/2019       League       AD Russell
#
# ...

# %%
df.groupby('winner').size().sort_values(ascending=False)
# Out:
# winner
# Mumbai Indians                 99
# Chennai Super Kings            92
# Kolkata Knight Riders          88
# Royal Challengers Bangalore    79
# Kings XI Punjab                77
# Rajasthan Royals               70
# Delhi Daredevils               67
# Sunrisers Hyderabad            53
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Delhi Capitals                  1
# dtype: int64

# %%
df[df["result_margin"] > 50]
# Out:
#           id   season            city       date   match_type  \
# 0     335982  2007/08       Bangalore  4/18/2008       League
# 9     335991  2007/08      Chandigarh  4/25/2008       League
# 39    336023  2007/08          Jaipur  5/17/2008       League
# 55    336038  2007/08          Mumbai  5/30/2008   Semi Final
# 59    392182     2009       Cape Town  4/18/2009       League
# 62    392185     2009  Port Elizabeth  4/20/2009       League
# 72    392197     2009  Port Elizabeth  4/27/2009       League
# 84    392209     2009     East London   5/4/2009       League
# 85    392210     2009          Durban   5/5/2009       League
# 95    392220     2009       Kimberley  5/11/2009       League
# 122   419113  2009/10         Kolkata  3/16/2010       League
# 123   419114  2009/10           Delhi  3/17/2010       League
# 143   419134  2009/10           Delhi  3/31/2010       League
# 147   419138  2009/10          Mumbai   4/3/2010       League
# ...

# %%
df.groupby('player_of_match').size().sort_values(ascending=False).head(5)
# Out:
# player_of_match
# CH Gayle          21
# AB de Villiers    18
# YK Pathan         16
# RG Sharma         16
# DA Warner         15
# dtype: int64

# %%
df[df["result"] == "wickets"]
# Out:
#           id   season       city       date match_type  player_of_match  \
# 2     335984  2007/08      Delhi  4/19/2008     League      MF Maharoof
# 3     335985  2007/08     Mumbai  4/20/2008     League       MV Boucher
# 4     335986  2007/08    Kolkata  4/20/2008     League        DJ Hussey
# 5     335987  2007/08     Jaipur  4/21/2008     League        SR Watson
# 6     335988  2007/08  Hyderabad  4/22/2008     League         V Sehwag
# ..       ...      ...        ...        ...        ...              ...
# 695  1136620     2018     Mumbai  5/27/2018      Final        SR Watson
# 696  1175356     2019    Chennai  3/23/2019     League  Harbhajan Singh
# 697  1175357     2019    Kolkata  3/24/2019     League       AD Russell
# 700  1175360     2019      Delhi  3/26/2019     League        SR Watson
# 703  1175363     2019  Hyderabad  3/29/2019     League      Rashid Khan
#
#                                          venue                        team1  \
# ...

# %%
df["city"].value_counts().head(1)
# Out:
# city
# Mumbai    95
# Name: count, dtype: int64

# %%
df.groupby('venue').size().sort_values(ascending=False)
# Out:
# venue
# Eden Gardens                                            72
# Wankhede Stadium                                        67
# M Chinnaswamy Stadium                                   65
# Feroz Shah Kotla                                        60
# Rajiv Gandhi International Stadium, Uppal               49
# MA Chidambaram Stadium, Chepauk                         48
# Sawai Mansingh Stadium                                  41
# Punjab Cricket Association Stadium, Mohali              35
# Maharashtra Cricket Association Stadium                 22
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              16
# Kingsmead                                               15
# SuperSport Park                                         12
# Sardar Patel Stadium, Motera                            12
# Punjab Cricket Association IS Bindra Stadium, Mohali    11
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# ...

# %%
df["toss_winner_won"] = df["toss_winner"] == df["winner"]
print(df)
# Out:
#           id   season        city       date match_type player_of_match  \
# 0     335982  2007/08   Bangalore  4/18/2008     League     BB McCullum
# 1     335983  2007/08  Chandigarh  4/19/2008     League      MEK Hussey
# 2     335984  2007/08       Delhi  4/19/2008     League     MF Maharoof
# 3     335985  2007/08      Mumbai  4/20/2008     League      MV Boucher
# 4     335986  2007/08     Kolkata  4/20/2008     League       DJ Hussey
# ..       ...      ...         ...        ...        ...             ...
# 699  1175359     2019      Jaipur  3/25/2019     League        CH Gayle
# 700  1175360     2019       Delhi  3/26/2019     League       SR Watson
# 701  1175361     2019     Kolkata  3/27/2019     League      AD Russell
# 702  1175362     2019   Bengaluru  3/28/2019     League       JJ Bumrah
# 703  1175363     2019   Hyderabad  3/29/2019     League     Rashid Khan
#
#                                           venue                        team1  \
# ...
